# %%
import os
import csv

full_path = os.getcwd() + "\PyElections_Resources.csv"
#fullpath = os.path.join(".","Python-Challenge","PyElections_Resources.csv")
with open(full_path) as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    for row in csvreader:
        print(row)
# Out:
# ['Candidate', 'County', 'Voter ID']
# ['Dwight A. Boykins', 'Harris County', '3363684']
# ['Bill King', 'Fort Bend County', '6114041']
# ['Sylvester Turner', 'Fort Bend County', '9143483']
# ['Bill King', 'Fort Bend County', '3122710']
# ['Sylvester Turner', 'Montgomery County', '6824440']
# ['Tony Buzbee', 'Montgomery County', '7836411']
# ['Bill King', 'Fort Bend County', '9208684']
# ['Sylvester Turner', 'Harris County', '8194291']
# ['Dwight A. Boykins', 'Harris County', '6528938']
# ['Sylvester Turner', 'Fort Bend County', '8402140']
# ['Sylvester Turner', 'Montgomery County', '1299337']
# ['Bill King', 'Harris County', '8828354']
# ['Sylvester Turner', 'Montgomery County', '8347747']
# ['Sylvester Turner', 'Harris County', '2234427']
# ['Tony Buzbee', 'Fort Bend County', '3459282']
# ['Tony Buzbee', 'Harris County', '7857738']
# ['Sylvester Turner', 'Fort Bend County', '6028629']
# ['Tony Buzbee', 'Harris County', '3158879']
# ['Tony Buzbee', 'Harris County', '5189665']
# ...

# %%
pwd
# Out:
# 'C:\\Users\\aadol\\Documents\\GitHub\\Python-Challenge'

# %%
import csv
import os
f = open ("C:\\Users\\aadol\\Documents\\GitHub\Python-Challenge\\PyElections_Resources.csv","rb")
csvreader = csv.reader(f)
for row in csvreader:
    print (row)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-21-399d80ee753d> in <module>
#       3 f = open ("C:\\Users\\aadol\\Documents\\GitHub\Python-Challenge\\PyElections_Resources.csv","rb")
#       4 csvreader = csv.reader(f)
# ----> 5 for row in csvreader:
#       6     print (row)
#
# Error: iterator should return strings, not bytes (did you open the file in text mode?)
